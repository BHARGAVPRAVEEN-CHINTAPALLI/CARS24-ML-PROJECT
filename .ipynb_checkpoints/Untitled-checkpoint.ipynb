# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Final_dataset.csv")

# %%
df.head()
# Out:
#         Brand    Model                 Variant  Year Engine_Type Transmission  \
# 0         KIA    SONET        HTK PLUS 1.0 IMT  2022      Petrol       Manual
# 1      Maruti    Dzire                     LXI  2018      Petrol       Manual
# 2      Maruti    FRONX        DELTA PLUS 1.2MT  2023      Petrol       Manual
# 3  Volkswagen   TAIGUN  COMFORTLINE 1.0 TSI MT  2022      Petrol       Manual
# 4       Skoda  Octavia          L&K 1.8 TSI AT  2019      Petrol         Auto
#
#    Driven_Kms EMI_per_Month  Price(In_Lakhs) Number Location     Status
# 0       43447         10968             6.21  DL-5C    delhi  Available
# 1       87050          5252             2.98  DL-6C    delhi  Available
# 2       25983         11739             6.65  HR-87    delhi  Available
# 3       62917         11748             6.66  DL-12    delhi  Available
# 4       86649         17961            10.49  DL-10    delhi  Available

# %%
df[df["Driven_Kms"] > 500000]
# Out:
#           Brand        Model                        Variant  Year Engine_Type  \
# 1448    Hyundai    Elite i20                 MAGNA PLUS 1.2  2019         CNG
# 3219    Hyundai    Grand i10  1.2 SPORTZ PRIME EDITION VTVT  2016         CNG
# 3569    Hyundai    Grand i10          SPORTZ 1.2 KAPPA VTVT  2017      Petrol
# 3586       Tata        NEXON              XM SUNROOF PETROL  2022      Petrol
# 4859   Mahindra       XUV300                  W6 1.2 PETROL  2020      Petrol
# 5538        KIA       SELTOS                 HTX 1.5 PETROL  2020      Petrol
# 7062       Tata        NEXON            XZA PLUS (O) PETROL  2022      Petrol
# 9133     Maruti       Baleno               DELTA PETROL 1.2  2016      Petrol
# 9891         MG       HECTOR               SHARP 2.0 DIESEL  2021      Diesel
# 10496    Maruti         Eeco             5 STR WITH A/C+HTR  2018         CNG
# 10975      Audi           Q5                2.0 TDI QUATTRO  2011      Diesel
# 11545   Renault        Lodgy        85 PS RXL STEPWAY 8 STR  2018      Diesel
# 12044   Hyundai    Elite i20                 MAGNA PLUS 1.2  2019         CNG
# 13149   Hyundai          i20                  SPORTZ 1.4 AT  2012      Petrol
# 13317    Maruti       Baleno               ALPHA PETROL 1.2  2016         CNG
# 13506    Maruti  New Wagon-R                    LXI CNG 1.0  2019         CNG
# 13645  Mahindra         Xylo                             E9  2012      Diesel
#
#       Transmission  Driven_Kms  EMI_per_Month  Price(In_Lakhs) Number  \
# 1448        Manual      539225           8342             3.75  DL-5C
# 3219        Manual      700020           8802             2.65  DL-8C
# 3569        Manual      805000           6540             2.94  UP-14
# 3586        Manual      736666          12544             5.64  DL-3C
# 4859        Manual      600000          14615             6.57  DL-12
# 5538        Manual      570301          21025             9.67  UP-14
# 7062          Auto     1035000          22503            10.35  KA-51
# 9133        Manual     7890087           8631             3.88  TS-09
# 9891        Manual     1760001          25004            11.50  TS-07
# 10496       Manual     1300000           5895             2.65  GJ-07
# 10975         Auto      650001  Not Avaliable             8.10  GJ-01
# 11545       Manual    16700000           9521             4.28  TN-10
# 12044       Manual      539225           8342             3.75  DL-5C
# 13149         Auto      800001          13327             1.50  MH-03
# 13317       Manual      675000          12289             3.70  MH-46
# 13506       Manual      593300           7919             3.56  MH-05
# 13645       Manual      750000  Not Avaliable             2.27  MH-02
#
#         Location     Status
# 1448       delhi  Available
# 3219       delhi  Available
# 3569       delhi  Available
# 3586       delhi  Available
# 4859       delhi  Available
# 5538       delhi  Available
# 7062   bangalore  Available
# 9133   hyderabad  Available
# 9891   hyderabad  Available
# 10496  ahmedabad  Available
# 10975  ahmedabad  Available
# 11545    chennai  Available
# 12044    Gurgaon  Available
# 13149     mumbai  Available
# 13317     mumbai  Available
# 13506     mumbai  Available
# 13645     mumbai  Available

# %%
data.to_csv("Errors_in_Webpage.csv",index=False)

# %%
df["Transmission"].value_counts()
# Out:
# Transmission
# Manual    11754
# Auto       3919
# Name: count, dtype: int64

# %%
df["Location"].value_counts()
# Out:
# Location
# delhi        5819
# bangalore    2470
# mumbai       1832
# hyderabad    1751
# pune         1480
# ahmedabad    1000
# chennai       721
# Gurgaon       600
# Name: count, dtype: int64

# %%
df["Status"].value_counts()
# Out:
# Status
# Available    15156
# BOOKED         517
# Name: count, dtype: int64

# %%
# ══════════════════════════════════════════════════
# STEP 1: Fix Location inconsistency
# ══════════════════════════════════════════════════
# "Gurgaon" has capital G, others are lowercase
# Standardize ALL to Title Case
df['Location'] = df['Location'].str.strip().str.title()

print("Location after fixing:")
print(df['Location'].value_counts())
# Should now show: Delhi, Bangalore, Mumbai... all consistent

# ══════════════════════════════════════════════════
# STEP 2: Handle EMI_per_Month properly
# ══════════════════════════════════════════════════
print("\nSample EMI values:")
print(df['EMI_per_Month'].value_counts().head(10))

# It has "Not Available" strings mixed with numbers
# Since we're dropping it anyway — just drop directly
# No need to convert it
df.drop('EMI_per_Month', axis=1, inplace=True)
print("✅ EMI_per_Month dropped (data leakage)")

# ══════════════════════════════════════════════════
# STEP 3: Handle Status
# ══════════════════════════════════════════════════
# BOOKED vs Available doesn't affect what price SHOULD be
# A ₹10L car is still worth ₹10L whether booked or not
df.drop('Status', axis=1, inplace=True)
print("✅ Status dropped (not a price factor)")

# ══════════════════════════════════════════════════
# STEP 4: Extract info from Number (RTO codes)
# ══════════════════════════════════════════════════
print("\nSample Number values:")
print(df['Number'].value_counts().head(15))

# Map RTO prefix to State
rto_to_state = {
    'DL': 'Delhi',
    'HR': 'Haryana',
    'MH': 'Maharashtra',
    'KA': 'Karnataka',
    'TN': 'Tamil Nadu',
    'RJ': 'Rajasthan',
    'UP': 'Uttar Pradesh',
    'GJ': 'Gujarat',
    'TS': 'Telangana',
    'AP': 'Andhra Pradesh',
    'KL': 'Kerala',
    'PB': 'Punjab',
    'MP': 'Madhya Pradesh',
    'WB': 'West Bengal',
    'GA': 'Goa',
    'BR': 'Bihar'
}

df['State'] = df['Number'].str[:2].str.upper().map(rto_to_state)

print("\nState mapping result:")
print(df['State'].value_counts())
print(f"Unmapped (NaN): {df['State'].isnull().sum()}")

# BH series flag
df['is_BH_series'] = df['Number'].str.upper().str.startswith('BH').astype(int)
print(f"\nBH Series cars: {df['is_BH_series'].sum()}")

# Drop Number after extraction
df.drop('Number', axis=1, inplace=True)

# ══════════════════════════════════════════════════
# STEP 5: Fill unmapped States using Location
# ══════════════════════════════════════════════════
# Some RTO codes won't map — fill using city name
city_to_state = {
    'Delhi':     'Delhi',
    'Bangalore': 'Karnataka',
    'Mumbai':    'Maharashtra',
    'Hyderabad': 'Telangana',
    'Pune':      'Maharashtra',
    'Ahmedabad': 'Gujarat',
    'Chennai':   'Tamil Nadu',
    'Gurgaon':   'Haryana'
}

# Where State is null, fill from Location
df['State'] = df['State'].fillna(df['Location'].map(city_to_state))

print("\nState after filling from Location:")
print(df['State'].value_counts())
print(f"Still unmapped: {df['State'].isnull().sum()}")

# ══════════════════════════════════════════════════
# STEP 6: Car_Age from Year
# ══════════════════════════════════════════════════
df['Car_Age'] = 2025 - df['Year']
df.drop('Year', axis=1, inplace=True)

print("\nCar Age distribution:")
print(df['Car_Age'].value_counts().sort_index())

# ══════════════════════════════════════════════════
# STEP 7: Clean Driven_Kms
# ══════════════════════════════════════════════════
print("\nDriven_Kms stats:")
print(df['Driven_Kms'].describe())

df = df[(df['Driven_Kms'] > 500) & (df['Driven_Kms'] < 400000)]

# ══════════════════════════════════════════════════
# STEP 8: Extract from Variant → then drop
# ══════════════════════════════════════════════════
print(f"\nUnique Variants: {df['Variant'].nunique()}")
print("Sample:", df['Variant'].head(10).tolist())

top_trim_keywords = [
    'ZXI', 'ZDI', 'ASTA', 'ALPHA', 'TITANIUM',
    'SPORTZ', 'PLUS', 'AT', 'AMT', 'CVT', 'DCT',
    'COMFORTLINE', 'HIGHLINE', 'TOPLINE', 'STYLE',
    'ELEGANCE', 'LUXURY', 'PREMIUM', 'TOP'
]

df['is_top_trim'] = df['Variant'].str.upper().apply(
    lambda x: 1 if any(kw in str(x) for kw in top_trim_keywords) else 0
)
print(f"\nTop trim: {df['is_top_trim'].sum()} cars")
print(f"Base trim: {(df['is_top_trim']==0).sum()} cars")

df.drop('Variant', axis=1, inplace=True)

# ══════════════════════════════════════════════════
# STEP 9: Group rare Brands
# ══════════════════════════════════════════════════
print(f"\nUnique Brands: {df['Brand'].nunique()}")
print(df['Brand'].value_counts())

top_brands = df['Brand'].value_counts().nlargest(15).index
df['Brand'] = df['Brand'].apply(
    lambda x: x if x in top_brands else 'Other'
)
print("\nAfter grouping:")
print(df['Brand'].value_counts())

# ══════════════════════════════════════════════════
# STEP 10: Group rare Models
# ══════════════════════════════════════════════════
print(f"\nUnique Models: {df['Model'].nunique()}")
model_counts = df['Model'].value_counts()
df['Model'] = df['Model'].apply(
    lambda x: x if model_counts[x] >= 30 else 'Other'
)
print(f"After grouping: {df['Model'].nunique()} unique models")

# ══════════════════════════════════════════════════
# STEP 11: Clean Price — rename + remove outliers
# ══════════════════════════════════════════════════
df.rename(columns={'Price(In_Lakhs)': 'Price_In_Lakhs'}, inplace=True)

df.dropna(subset=['Price_In_Lakhs'], inplace=True)

Q1  = df['Price_In_Lakhs'].quantile(0.25)
Q3  = df['Price_In_Lakhs'].quantile(0.75)
IQR = Q3 - Q1
df  = df[
    (df['Price_In_Lakhs'] >= Q1 - 1.5*IQR) &
    (df['Price_In_Lakhs'] <= Q3 + 1.5*IQR)
]

print("\nPrice stats after cleaning:")
print(df['Price_In_Lakhs'].describe())

# ══════════════════════════════════════════════════
# FINAL SUMMARY
# ══════════════════════════════════════════════════
print("\n" + "="*50)
print("FINAL DATASET")
print("="*50)
print(f"Shape       : {df.shape}")
print(f"Columns     : {df.columns.tolist()}")
print(f"Missing vals:\n{df.isnull().sum()}")
print(f"\nSample:\n{df.head(3)}")

df.to_csv("cars24_cleaned_happy.csv", index=False)
print("\n✅ Saved as cars24_cleaned.csv")
# Out:
# Location after fixing:
# Location
# Delhi        5819
# Bangalore    2470
# Mumbai       1832
# Hyderabad    1751
# Pune         1480
# Ahmedabad    1000
# Chennai       721
# Gurgaon       600
# Name: count, dtype: int64
#
# Sample EMI values:
# EMI_per_Month
# Not Avaliable    1799
# 14554              56
# 11474              54
# 10592              51
# 12357              44
# 13240              42
# 7061               32
# 7944               32
# 13698              31
# 17979              31
# Name: count, dtype: int64
# ✅ EMI_per_Month dropped (data leakage)
# ✅ Status dropped (not a price factor)
#
# Sample Number values:
# Number
# MH-12    681
# UP-16    592
# DL-8C    546
# GJ-01    504
# HR-26    486
# UP-14    464
# DL-3C    459
# MH-14    438
# KA-03    418
# TS-07    373
# MH-02    363
# DL-10    355
# KA-05    346
# DL-9C    324
# DL-12    299
# Name: count, dtype: int64
#
# State mapping result:
# State
# Delhi             3385
# Maharashtra       3220
# Karnataka         2360
# Haryana           1509
# Uttar Pradesh     1341
# Telangana         1217
# Gujarat           1022
# Tamil Nadu         728
# Andhra Pradesh     373
# West Bengal         42
# Rajasthan           35
# Punjab              32
# Madhya Pradesh      23
# Bihar               21
# Kerala              11
# Goa                  9
# Name: count, dtype: int64
# Unmapped (NaN): 345
#
# BH Series cars: 0
#
# State after filling from Location:
# State
# Delhi             3517
# Maharashtra       3279
# Karnataka         2386
# Haryana           1519
# Uttar Pradesh     1341
# Telangana         1324
# Gujarat           1026
# Tamil Nadu         735
# Andhra Pradesh     373
# West Bengal         42
# Rajasthan           35
# Punjab              32
# Madhya Pradesh      23
# Bihar               21
# Kerala              11
# Goa                  9
# Name: count, dtype: int64
# Still unmapped: 0
#
# Car Age distribution:
# Car_Age
# 0      149
# 1      515
# 2      908
# 3     1245
# 4     1317
# 5      960
# 6     1268
# 7     1405
# 8     1451
# 9     1440
# 10    1236
# 11    1040
# 12     881
# 13     819
# 14    1001
# 15      34
# 16       1
# 17       1
# 18       1
# 19       1
# Name: count, dtype: int64
#
# Driven_Kms stats:
# count    1.567300e+04
# mean     7.741001e+04
# std      1.552868e+05
# min      1.000000e+00
# 25%      4.321500e+04
# 50%      6.940900e+04
# 75%      9.779000e+04
# max      1.670000e+07
# Name: Driven_Kms, dtype: float64
#
# Unique Variants: 2054
# Sample: ['HTK PLUS 1.0 IMT', 'LXI', 'DELTA PLUS 1.2MT', 'COMFORTLINE 1.0 TSI MT', 'L&K 1.8 TSI AT', 'ADVENTURE MT', 'XT PETROL', 'ALPHA SMART HYBRID', 'TREND 1.5L PETROL', 'VXi']
#
# Top trim: 6523 cars
# Base trim: 9112 cars
#
# Unique Brands: 31
# Brand
# Maruti        4429
# Hyundai       3328
# Tata          1482
# Honda         1386
# Mahindra       838
# KIA            623
# Renault        614
# Ford           560
# Toyota         455
# Volkswagen     423
# Skoda          342
# MG             326
# Nissan         192
# Jeep           138
# Chevrolet       95
# Audi            79
# Datsun          79
# BMW             76
# Mercedes        57
# Fiat            24
# CITROEN         24
# Volvo           21
# Landrover       11
# Jaguar          11
# Mitsubishi       7
# Ssangyong        5
# ISUZU            4
# Porsche          3
# Force            1
# BYD              1
# Ashok            1
# Name: count, dtype: int64
#
# After grouping:
# Brand
# Maruti        4429
# Hyundai       3328
# Tata          1482
# Honda         1386
# Mahindra       838
# KIA            623
# Renault        614
# Ford           560
# Toyota         455
# Volkswagen     423
# Other          404
# Skoda          342
# MG             326
# Nissan         192
# Jeep           138
# Chevrolet       95
# Name: count, dtype: int64
#
# Unique Models: 276
# After grouping: 94 unique models
#
# Price stats after cleaning:
# count    14907.000000
# mean         4.766487
# std          2.816611
# min          0.270000
# 25%          2.600000
# 50%          4.150000
# 75%          6.400000
# max         13.200000
# Name: Price_In_Lakhs, dtype: float64
#
# ==================================================
# FINAL DATASET
# ==================================================
# Shape       : (14907, 11)
# Columns     : ['Brand', 'Model', 'Engine_Type', 'Transmission', 'Driven_Kms', 'Price_In_Lakhs', 'Location', 'State', 'is_BH_series', 'Car_Age', 'is_top_trim']
# Missing vals:
# Brand             0
# Model             0
# Engine_Type       0
# Transmission      0
# Driven_Kms        0
# Price_In_Lakhs    0
# Location          0
# State             0
# is_BH_series      0
# Car_Age           0
# is_top_trim       0
# dtype: int64
#
# Sample:
#     Brand  Model Engine_Type Transmission  Driven_Kms  Price_In_Lakhs  \
# 0     KIA  SONET      Petrol       Manual       43447            6.21
# 1  Maruti  Dzire      Petrol       Manual       87050            2.98
# 2  Maruti  FRONX      Petrol       Manual       25983            6.65
#
#   Location    State  is_BH_series  Car_Age  is_top_trim
# 0    Delhi    Delhi             0        3            1
# 1    Delhi    Delhi             0        7            0
# 2    Delhi  Haryana             0        2            1
#
# ✅ Saved as cars24_cleaned.csv

# %%
## What Your Final Dataset Should Look Like
```
Columns (11 total):
──────────────────────────────────────────
Brand          → Maruti, KIA, Volkswagen...
Model          → Swift, Sonet, Dzire...
Engine_Type    → Petrol / Diesel
Transmission   → Manual / Auto
Car_Age        → 3, 5, 7... (from Year)
Driven_Kms     → Cleaned numeric
Location       → Delhi, Bangalore... (city)
State          → Delhi, Karnataka...  (from RTO)
is_top_trim    → 1 or 0
is_BH_series   → 1 or 0

Price_In_Lakhs → 🎯 TARGET
```

---

## One Important Question Before You Run This
```
Your Location has 8 CITIES
Your State extracted from RTO will have more variety

You now have BOTH city and state level data.
This is actually MORE powerful than just state.

# %%
df = pd.read_csv("cars24_cleaned_happy.csv")

# %%
df.head()
# Out:
#         Brand    Model Engine_Type Transmission  Driven_Kms  Price_In_Lakhs  \
# 0         KIA    SONET      Petrol       Manual       43447            6.21
# 1      Maruti    Dzire      Petrol       Manual       87050            2.98
# 2      Maruti    FRONX      Petrol       Manual       25983            6.65
# 3  Volkswagen   TAIGUN      Petrol       Manual       62917            6.66
# 4       Skoda  Octavia      Petrol         Auto       86649           10.49
#
#   Location    State  is_BH_series  Car_Age  is_top_trim
# 0    Delhi    Delhi             0        3            1
# 1    Delhi    Delhi             0        7            0
# 2    Delhi  Haryana             0        2            1
# 3    Delhi    Delhi             0        3            1
# 4    Delhi    Delhi             0        6            1

# %%
df["State"].value_counts()
# Out:
# State
# Delhi             3399
# Maharashtra       3118
# Karnataka         2280
# Haryana           1446
# Uttar Pradesh     1251
# Telangana         1184
# Gujarat            999
# Tamil Nadu         711
# Andhra Pradesh     354
# West Bengal         39
# Rajasthan           33
# Punjab              30
# Madhya Pradesh      23
# Bihar               20
# Kerala              11
# Goa                  9
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# Brand             0
# Model             0
# Engine_Type       0
# Transmission      0
# Driven_Kms        0
# Price_In_Lakhs    0
# Location          0
# State             0
# is_BH_series      0
# Car_Age           0
# is_top_trim       0
# dtype: int64

# %%
df["is_BH_series"].value_counts()
# Out:
# is_BH_series
# 0    14907
# Name: count, dtype: int64

# %%
df["is_top_trim"].value_counts()
# Out:
# is_top_trim
# 0    8822
# 1    6085
# Name: count, dtype: int64

# %%
df.drop('is_BH_series', axis=1, inplace=True)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# Load your cleaned data

# Clean styling for all charts
plt.style.use('seaborn-v0_8')
sns.set_palette("husl")
pd.set_option('display.float_format', '{:.2f}'.format)

print("Shape:", df.shape)
print("Columns:", df.columns.tolist())
# Out:
# Shape: (14907, 10)
# Columns: ['Brand', 'Model', 'Engine_Type', 'Transmission', 'Driven_Kms', 'Price_In_Lakhs', 'Location', 'State', 'Car_Age', 'is_top_trim']

# %%
print("="*50)
print("PRICE ANALYSIS")
print("="*50)
print(f"Lowest Price  : ₹{df['Price_In_Lakhs'].min():.2f} Lakhs")
print(f"Highest Price : ₹{df['Price_In_Lakhs'].max():.2f} Lakhs")
print(f"Average Price : ₹{df['Price_In_Lakhs'].mean():.2f} Lakhs")
print(f"Median Price  : ₹{df['Price_In_Lakhs'].median():.2f} Lakhs")
print(f"Std Deviation : ₹{df['Price_In_Lakhs'].std():.2f} Lakhs")

# Plot
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Raw distribution
axes[0].hist(df['Price_In_Lakhs'], bins=50, 
             color='steelblue', edgecolor='white')
axes[0].set_title('Price Distribution (Raw)', fontsize=14)
axes[0].set_xlabel('Price in Lakhs')
axes[0].set_ylabel('Number of Cars')
axes[0].axvline(df['Price_In_Lakhs'].mean(), 
                color='red', linestyle='--', label='Mean')
axes[0].axvline(df['Price_In_Lakhs'].median(), 
                color='green', linestyle='--', label='Median')
axes[0].legend()

# Log distribution
axes[1].hist(np.log1p(df['Price_In_Lakhs']), bins=50, 
             color='coral', edgecolor='white')
axes[1].set_title('Price Distribution (Log Scale)', fontsize=14)
axes[1].set_xlabel('Log of Price')
axes[1].set_ylabel('Number of Cars')

plt.suptitle('How Are Car Prices Distributed?', 
             fontsize=16, fontweight='bold')
plt.tight_layout()
plt.savefig('01_price_distribution.png', dpi=150)
plt.show()
#```

### What to check:
#```
#If Raw chart is skewed right (long tail) → 
#Confirms we need log transformation in Stage 4 ✅

#If Mean > Median → 
#Expensive cars are pulling the average up (normal for cars)
# Out:
# ==================================================
# PRICE ANALYSIS
# ==================================================
# Lowest Price  : ₹0.27 Lakhs
# Highest Price : ₹13.20 Lakhs
# Average Price : ₹4.77 Lakhs
# Median Price  : ₹4.15 Lakhs
# Std Deviation : ₹2.82 Lakhs

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Scatter plot
axes[0].scatter(df['Car_Age'], df['Price_In_Lakhs'],
                alpha=0.2, color='steelblue', s=10)
axes[0].set_title('Car Age vs Price (All Cars)', fontsize=14)
axes[0].set_xlabel('Car Age (Years)')
axes[0].set_ylabel('Price (Lakhs)')

# Average price by age — the depreciation curve
avg_by_age = df.groupby('Car_Age')['Price_In_Lakhs'].mean()
axes[1].plot(avg_by_age.index, avg_by_age.values,
             marker='o', color='coral', linewidth=2.5)
axes[1].fill_between(avg_by_age.index, avg_by_age.values, 
                     alpha=0.2, color='coral')
axes[1].set_title('Average Price by Car Age\n(Depreciation Curve)', 
                  fontsize=14)
axes[1].set_xlabel('Car Age (Years)')
axes[1].set_ylabel('Avg Price (Lakhs)')

plt.suptitle('Does Older Age = Lower Price?', 
             fontsize=16, fontweight='bold')
plt.tight_layout()
plt.savefig('02_age_vs_price.png', dpi=150)
plt.show()

# Correlation
corr = df['Car_Age'].corr(df['Price_In_Lakhs'])
print(f"Correlation — Car Age vs Price: {corr:.3f}")
print("Interpretation:", 
      "Older car → Lower price ✅" if corr < 0 else "Unexpected! Check data")

# Depreciation insight
age_1 = df[df['Car_Age']==1]['Price_In_Lakhs'].mean()
age_5 = df[df['Car_Age']==5]['Price_In_Lakhs'].mean()
age_10 = df[df['Car_Age']==10]['Price_In_Lakhs'].mean()
print(f"\nAverage price at 1 year  : ₹{age_1:.2f} Lakhs")
print(f"Average price at 5 years : ₹{age_5:.2f} Lakhs")
print(f"Average price at 10 years: ₹{age_10:.2f} Lakhs")
print(f"\nDepreciation 1→5 years   : ₹{age_1 - age_5:.2f} Lakhs")
print(f"Depreciation 5→10 years  : ₹{age_5 - age_10:.2f} Lakhs")
# Out:
# Correlation — Car Age vs Price: -0.699
# Interpretation: Older car → Lower price ✅
#
# Average price at 1 year  : ₹8.39 Lakhs
# Average price at 5 years : ₹6.66 Lakhs
# Average price at 10 years: ₹3.35 Lakhs
#
# Depreciation 1→5 years   : ₹1.73 Lakhs
# Depreciation 5→10 years  : ₹3.30 Lakhs

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Scatter
axes[0].scatter(df['Driven_Kms'], df['Price_In_Lakhs'],
                alpha=0.2, color='green', s=10)
axes[0].set_title('Driven KMs vs Price', fontsize=14)
axes[0].set_xlabel('Driven KMs')
axes[0].set_ylabel('Price (Lakhs)')

# Bucket KMs into ranges
df['km_bucket'] = pd.cut(
    df['Driven_Kms'],
    bins=[0, 20000, 40000, 60000, 80000, 
          100000, 150000, 400000],
    labels=['0-20k', '20-40k', '40-60k', 
            '60-80k', '80-100k', '100-150k', '150k+']
)

avg_by_km = df.groupby('km_bucket', observed=True)['Price_In_Lakhs'].mean()
axes[1].bar(avg_by_km.index, avg_by_km.values, 
            color='mediumseagreen', edgecolor='white')
axes[1].set_title('Average Price by KM Range', fontsize=14)
axes[1].set_xlabel('KMs Driven')
axes[1].set_ylabel('Avg Price (Lakhs)')
axes[1].tick_params(axis='x', rotation=45)

plt.suptitle('Does More KMs = Lower Price?', 
             fontsize=16, fontweight='bold')
plt.tight_layout()
plt.savefig('03_km_vs_price.png', dpi=150)
plt.show()

# Clean up temp column
df.drop('km_bucket', axis=1, inplace=True)

corr_km = df['Driven_Kms'].corr(df['Price_In_Lakhs'])
print(f"Correlation — Driven KMs vs Price: {corr_km:.3f}")
# Out:
# Correlation — Driven KMs vs Price: -0.255

# %%
petrol = df[df['Engine_Type'] == 'Petrol']['Price_In_Lakhs']
diesel = df[df['Engine_Type'] == 'Diesel']['Price_In_Lakhs']

print("="*50)
print("PETROL vs DIESEL — Statistical Test")
print("="*50)
print(f"Petrol cars : {len(petrol)} cars | Avg: ₹{petrol.mean():.2f}L")
print(f"Diesel cars : {len(diesel)} cars | Avg: ₹{diesel.mean():.2f}L")
print(f"Price difference: ₹{abs(diesel.mean()-petrol.mean()):.2f} Lakhs")

# T-Test
t_stat, p_value = stats.ttest_ind(petrol, diesel)
print(f"\nT-statistic : {t_stat:.3f}")
print(f"P-value     : {p_value:.6f}")

if p_value < 0.05:
    higher = "Diesel" if diesel.mean() > petrol.mean() else "Petrol"
    print(f"\n✅ {higher} cars are statistically MORE expensive")
    print("   (p < 0.05 → This is NOT by random chance)")
else:
    print("\n❌ No significant price difference between fuel types")

# Visualize
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

sns.boxplot(x='Engine_Type', y='Price_In_Lakhs', 
            data=df, ax=axes[0])
axes[0].set_title('Price by Engine Type (Box Plot)', fontsize=14)
axes[0].set_xlabel('Engine Type')
axes[0].set_ylabel('Price (Lakhs)')

sns.violinplot(x='Engine_Type', y='Price_In_Lakhs', 
               data=df, ax=axes[1])
axes[1].set_title('Price by Engine Type (Violin Plot)', fontsize=14)
axes[1].set_xlabel('Engine Type')
axes[1].set_ylabel('Price (Lakhs)')

plt.suptitle('Petrol vs Diesel — Price Comparison', 
             fontsize=16, fontweight='bold')
plt.tight_layout()
plt.savefig('04_petrol_vs_diesel.png', dpi=150)
plt.show()
# Out:
# ==================================================
# PETROL vs DIESEL — Statistical Test
# ==================================================
# Petrol cars : 9782 cars | Avg: ₹4.65L
# Diesel cars : 3179 cars | Avg: ₹5.80L
# Price difference: ₹1.15 Lakhs
#
# T-statistic : -20.220
# P-value     : 0.000000
#
# ✅ Diesel cars are statistically MORE expensive
#    (p < 0.05 → This is NOT by random chance)

# %%
manual = df[df['Transmission'] == 'Manual']['Price_In_Lakhs']
auto   = df[df['Transmission'] == 'Auto']['Price_In_Lakhs']

print("="*50)
print("MANUAL vs AUTOMATIC — Statistical Test")
print("="*50)
print(f"Manual cars    : {len(manual)} | Avg: ₹{manual.mean():.2f}L")
print(f"Automatic cars : {len(auto)}   | Avg: ₹{auto.mean():.2f}L")

t_stat2, p_value2 = stats.ttest_ind(manual, auto)
print(f"\nP-value: {p_value2:.6f}")

if p_value2 < 0.05:
    higher = "Automatic" if auto.mean() > manual.mean() else "Manual"
    print(f"✅ {higher} cars are statistically more expensive")
else:
    print("❌ No significant difference")

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

sns.boxplot(x='Transmission', y='Price_In_Lakhs', 
            data=df, ax=axes[0])
axes[0].set_title('Price by Transmission', fontsize=14)

sns.violinplot(x='Transmission', y='Price_In_Lakhs', 
               data=df, ax=axes[1])
axes[1].set_title('Price Spread by Transmission', fontsize=14)

plt.suptitle('Manual vs Automatic Price Comparison', 
             fontsize=16, fontweight='bold')
plt.tight_layout()
plt.savefig('05_transmission_vs_price.png', dpi=150)
plt.show()
# Out:
# ==================================================
# MANUAL vs AUTOMATIC — Statistical Test
# ==================================================
# Manual cars    : 11528 | Avg: ₹4.23L
# Automatic cars : 3379   | Avg: ₹6.59L
#
# P-value: 0.000000
# ✅ Automatic cars are statistically more expensive

# %%
brand_stats = df.groupby('Brand').agg(
    Avg_Price  = ('Price_In_Lakhs', 'mean'),
    Count      = ('Price_In_Lakhs', 'count'),
    Median     = ('Price_In_Lakhs', 'median')
).sort_values('Avg_Price', ascending=True)

fig, axes = plt.subplots(1, 2, figsize=(16, 7))

# Average price
axes[0].barh(brand_stats.index, brand_stats['Avg_Price'], 
             color='steelblue', edgecolor='white')
axes[0].set_title('Average Price by Brand', fontsize=14)
axes[0].set_xlabel('Average Price (Lakhs)')

# Car count
axes[1].barh(brand_stats.index, brand_stats['Count'], 
             color='coral', edgecolor='white')
axes[1].set_title('Number of Cars per Brand', fontsize=14)
axes[1].set_xlabel('Count')

plt.suptitle('Brand Analysis', fontsize=16, fontweight='bold')
plt.tight_layout()
plt.savefig('06_brand_analysis.png', dpi=150)
plt.show()

print("\nFull Brand Stats:")
print(brand_stats.to_string())
# Out:
# Full Brand Stats:
#             Avg_Price  Count  Median
# Brand
# Chevrolet        1.64     95    1.29
# Renault          3.59    614    3.17
# Ford             3.81    556    3.60
# Nissan           3.97    192    4.00
# Maruti           3.98   4418    3.66
# Honda            4.01   1383    3.68
# Volkswagen       4.34    411    3.52
# Hyundai          4.38   3265    3.79
# Toyota           4.93    388    4.23
# Other            5.68    309    5.63
# Tata             5.79   1395    5.50
# Skoda            6.06    296    5.63
# Mahindra         6.79    690    6.74
# Jeep             8.32    103    8.19
# KIA              9.26    551    9.15
# MG               9.95    241   10.00

# %%
location_avg = df.groupby('Location')['Price_In_Lakhs'].agg(
    ['mean', 'median', 'count']
).sort_values('mean', ascending=False)

print("Price by City:")
print(location_avg.to_string())

plt.figure(figsize=(12, 5))
bars = plt.bar(location_avg.index, location_avg['mean'], 
               color='mediumpurple', edgecolor='white')
plt.title('Average Car Price by City', fontsize=16, fontweight='bold')
plt.xlabel('City')
plt.ylabel('Average Price (Lakhs)')
plt.xticks(rotation=45)

# Add value labels
for bar, val in zip(bars, location_avg['mean']):
    plt.text(bar.get_x() + bar.get_width()/2,
             bar.get_height() + 0.05,
             f'₹{val:.1f}L', ha='center', 
             va='bottom', fontsize=9)

plt.tight_layout()
plt.savefig('07_location_analysis.png', dpi=150)
plt.show()
# Out:
# Price by City:
#            mean  median  count
# Location
# Bangalore  5.68    5.22   2362
# Chennai    5.48    4.94    698
# Hyderabad  5.20    4.60   1587
# Pune       4.72    4.12   1396
# Mumbai     4.54    3.97   1755
# Delhi      4.47    3.83   5552
# Ahmedabad  4.07    3.50    977
# Gurgaon    3.82    3.08    580

# %%
top   = df[df['is_top_trim'] == 1]['Price_In_Lakhs']
base  = df[df['is_top_trim'] == 0]['Price_In_Lakhs']

print("="*50)
print("TOP TRIM vs BASE TRIM")
print("="*50)
print(f"Top trim  : {len(top)} cars | Avg: ₹{top.mean():.2f}L")
print(f"Base trim : {len(base)} cars | Avg: ₹{base.mean():.2f}L")
print(f"Premium for top trim: ₹{top.mean() - base.mean():.2f} Lakhs")

t3, p3 = stats.ttest_ind(top, base)
print(f"P-value: {p3:.6f}")
print("✅ Statistically significant!" if p3 < 0.05 else "❌ Not significant")
# Out:
# ==================================================
# TOP TRIM vs BASE TRIM
# ==================================================
# Top trim  : 6085 cars | Avg: ₹5.69L
# Base trim : 8822 cars | Avg: ₹4.13L
# Premium for top trim: ₹1.55 Lakhs
# P-value: 0.000000
# ✅ Statistically significant!

# %%
# Only numeric columns
num_cols = ['Car_Age', 'Driven_Kms', 'is_top_trim', 'Price_In_Lakhs']
corr_matrix = df[num_cols].corr()

plt.figure(figsize=(8, 6))
sns.heatmap(
    corr_matrix,
    annot=True,
    fmt='.2f',
    cmap='RdYlGn',
    center=0,
    square=True,
    linewidths=0.5,
    annot_kws={'size': 12}
)
plt.title('Correlation Between Numeric Features', 
          fontsize=14, fontweight='bold')
plt.tight_layout()
plt.savefig('08_correlation_heatmap.png', dpi=150)
plt.show()

print("\nCorrelations with Price:")
print(corr_matrix['Price_In_Lakhs'].drop('Price_In_Lakhs')
      .sort_values(ascending=False).to_string())
# Out:
# Correlations with Price:
# is_top_trim    0.27
# Driven_Kms    -0.25
# Car_Age       -0.70

# %%
def check_outliers(col):
    Q1  = df[col].quantile(0.25)
    Q3  = df[col].quantile(0.75)
    IQR = Q3 - Q1
    low  = Q1 - 1.5 * IQR
    high = Q3 + 1.5 * IQR
    out  = df[(df[col] < low) | (df[col] > high)]
    print(f"\n{col}:")
    print(f"  Normal range : {low:.0f} → {high:.0f}")
    print(f"  Outliers     : {len(out)} rows ({len(out)/len(df)*100:.1f}%)")

for col in ['Price_In_Lakhs', 'Driven_Kms', 'Car_Age']:
    check_outliers(col)
# Out:
# Price_In_Lakhs:
#   Normal range : -3 → 12
#   Outliers     : 236 rows (1.6%)
#
# Driven_Kms:
#   Normal range : -36335 → 179865
#   Outliers     : 399 rows (2.7%)
#
# Car_Age:
#   Normal range : -4 → 20
#   Outliers     : 0 rows (0.0%)

# %% [markdown]
# ```
#
# ---
#
# ## After Running All Analysis — Your Findings Template
#
# Fill this in with your actual numbers and **put it in your README:**
# ```
# 📌 Finding 1: Average price is ₹X Lakhs, median ₹X Lakhs
#               (Mean > Median → luxury cars skew average up)
#
# 📌 Finding 2: Cars depreciate ₹X Lakhs from year 1→5
#               and ₹X Lakhs from year 5→10
#               (Steeper early depreciation confirmed)
#
# 📌 Finding 3: Diesel cars are ₹X Lakhs more expensive than petrol
#               (p = X → statistically significant ✅)
#
# 📌 Finding 4: Automatic cars command ₹X Lakhs premium over manual
#               (p = X → statistically significant ✅)
#
# 📌 Finding 5: [City X] has highest avg prices at ₹X Lakhs
#               [City Y] has lowest at ₹X Lakhs
#
# 📌 Finding 6: Top trim cars are ₹X Lakhs more expensive than base
#               ({X}% premium for higher variants)
#
# 📌 Finding 7: Car_Age has X correlation with price
#               Driven_Kms has X correlation with price
# ```
#
# ---
#
# ## All Charts You'll Have After This
# ```
# 01_price_distribution.png    ← Shows price spread
# 02_age_vs_price.png          ← Depreciation curve
# 03_km_vs_price.png           ← Usage vs value
# 04_petrol_vs_diesel.png      ← Statistical comparison
# 05_transmission_vs_price.png ← Manual vs Auto
# 06_brand_analysis.png        ← Brand value ranking
# 07_location_analysis.png     ← City wise pricing
# 08_correlation_heatmap.png   ← Feature relationships

# %%
# Remove price outliers
Q1 = df['Price_In_Lakhs'].quantile(0.25)
Q3 = df['Price_In_Lakhs'].quantile(0.75)
IQR = Q3 - Q1
df = df[
    (df['Price_In_Lakhs'] >= Q1 - 1.5*IQR) &
    (df['Price_In_Lakhs'] <= Q3 + 1.5*IQR)
]

# Remove KM outliers
Q1k = df['Driven_Kms'].quantile(0.25)
Q3k = df['Driven_Kms'].quantile(0.75)
IQRk = Q3k - Q1k
df = df[
    (df['Driven_Kms'] >= Q1k - 1.5*IQRk) &
    (df['Driven_Kms'] <= Q3k + 1.5*IQRk)
]

print(f"Final shape after outlier removal: {df.shape}")
# df.to_csv("cars24_final.csv", index=False)
# Out:
# Final shape after outlier removal: (14276, 10)

# %%
# Check exact counts
print(df['Engine_Type'].value_counts())

# Group small categories
major_engines = ['Petrol', 'Diesel']
df['Engine_Type'] = df['Engine_Type'].apply(
    lambda x: x if x in major_engines else 'Other'
)

print("\nAfter grouping:")
print(df['Engine_Type'].value_counts())
# Out:
# Engine_Type
# Petrol      9583
# Diesel      2846
# CNG         1778
# Electric      66
# Others         3
# Name: count, dtype: int64
#
# After grouping:
# Engine_Type
# Petrol    9583
# Diesel    2846
# Other     1847
# Name: count, dtype: int64

# %% [markdown]
# ```
#
# ---
#
# ## Your README Findings Block — Copy This!
# ```
# 📌 Finding 1: Average used car price is ₹4.77L
#               (median ₹4.15L — luxury cars skew the mean up)
#
# 📌 Finding 2: Car age is the #1 price driver (correlation -0.70)
#               Cars depreciate ₹1.73L from year 1→5,
#               then ₹3.30L more from year 5→10
#               (depreciation accelerates with age)
#
# 📌 Finding 3: Diesel cars command ₹1.15L premium over petrol
#               (p < 0.0001 — statistically proven)
#
# 📌 Finding 4: Automatic cars are ₹2.36L more expensive than manual
#               (p < 0.0001 — largest price gap found)
#
# 📌 Finding 5: Bangalore is the most expensive used car market (₹5.7L avg)
#               Gurgaon is the most affordable (₹3.8L avg)
#               ₹1.86L gap between most and least expensive city
#
# 📌 Finding 6: MG commands highest resale at ₹9.95L avg
#               Maruti dominates volume with 4,418 listings (28% of market)
#
# 📌 Finding 7: Top trim variants carry ₹1.55L premium over base trims
#               (p < 0.0001 — statistically proven)
# ```
#
# ---
#
# ## Your EDA Score
# ```
# Statistical tests run     : 3 (Petrol/Diesel, Manual/Auto, Top/Base trim)
# Charts produced           : 8
# Real insights found       : 7 documented findings
# Surprise discovery        : CNG + Electric cars in dataset
# Interview talking points  : 5+ strong ones
#
# EDA Quality Score         : 9/10 ✅

# %%
import pandas as pd
import numpy as np
import pickle
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Load the final cleaned file
#df = pd.read_csv("cars24_final.csv")

print("Shape:", df.shape)
print("Columns:", df.columns.tolist())
print("\nMissing values:", df.isnull().sum().sum())
print("\nEngine_Type counts:")
print(df['Engine_Type'].value_counts())
# Out:
# Shape: (14276, 10)
# Columns: ['Brand', 'Model', 'Engine_Type', 'Transmission', 'Driven_Kms', 'Price_In_Lakhs', 'Location', 'State', 'Car_Age', 'is_top_trim']
#
# Missing values: 0
#
# Engine_Type counts:
# Engine_Type
# Petrol    9583
# Diesel    2846
# Other     1847
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# Before and after visual proof
fig, axes = plt.subplots(1, 2, figsize=(14, 4))

axes[0].hist(df['Price_In_Lakhs'], bins=50, color='coral')
axes[0].set_title('Price BEFORE Log Transform')
axes[0].set_xlabel('Price (Lakhs)')

# Apply log transform
df['Price_Log'] = np.log1p(df['Price_In_Lakhs'])

axes[1].hist(df['Price_Log'], bins=50, color='steelblue')
axes[1].set_title('Price AFTER Log Transform')
axes[1].set_xlabel('Log Price')

plt.tight_layout()
plt.show()

print(f"Original price range : ₹{df['Price_In_Lakhs'].min():.2f} → ₹{df['Price_In_Lakhs'].max():.2f} Lakhs")
print(f"Log price range      : {df['Price_Log'].min():.3f} → {df['Price_Log'].max():.3f}")
# Out:
# Original price range : ₹0.27 → ₹12.10 Lakhs
# Log price range      : 0.239 → 2.573

# %%
# X = what model LEARNS FROM
# y = what model PREDICTS

X = df.drop(['Price_In_Lakhs', 'Price_Log'], axis=1)
y = df['Price_Log']

print("Input columns:", X.columns.tolist())
print("Input shape  :", X.shape)
print("Target shape :", y.shape)


#Your X columns at this point:

#Brand, Model, Engine_Type, Transmission,
#Driven_Kms, Location, State, Car_Age, is_top_trim


## STEP 4 — Encode Text Columns 🔢

#You have these text columns that need converting:

#Brand        → 16 unique brands
#Model        → many models
#Engine_Type  → Petrol, Diesel, Other
#Transmission → Manual, Auto
#Location     → 8 cities
#State        → 9 states + Other


### Why One-Hot Encoding for all of these:

#None of these have natural ORDER or RANK

#Petrol is not "greater" than Diesel
#Bangalore is not "bigger" than Delhi
#Maruti is not "less than" Honda

#They are just different CATEGORIES
#→ One-Hot Encoding is correct ✅
# Out:
# Input columns: ['Brand', 'Model', 'Engine_Type', 'Transmission', 'Driven_Kms', 'Location', 'State', 'Car_Age', 'is_top_trim']
# Input shape  : (14276, 9)
# Target shape : (14276,)

# %%
# Columns to encode
categorical_cols = ['Brand', 'Model', 'Engine_Type', 
                    'Transmission', 'Location', 'State']

# Check unique values before encoding
for col in categorical_cols:
    print(f"{col}: {df[col].nunique()} unique values")
# Out:
# Brand: 16 unique values
# Model: 94 unique values
# Engine_Type: 3 unique values
# Transmission: 2 unique values
# Location: 8 unique values
# State: 16 unique values

# %%
# Apply One-Hot Encoding
X = pd.get_dummies(
    X,
    columns=categorical_cols,
    drop_first=True    # Avoids duplicate information
)

print("\nShape BEFORE encoding: (14800, 9)")
print(f"Shape AFTER encoding : {X.shape}")
print(f"\nTotal features now   : {X.shape[1]}")
print("\nAll columns after encoding:")
print(X.columns.tolist())
# Out:
# Shape BEFORE encoding: (14800, 9)
# Shape AFTER encoding : (14276, 136)
#
# Total features now   : 136
#
# All columns after encoding:
# ['Driven_Kms', 'Car_Age', 'is_top_trim', 'Brand_Ford', 'Brand_Honda', 'Brand_Hyundai', 'Brand_Jeep', 'Brand_KIA', 'Brand_MG', 'Brand_Mahindra', 'Brand_Maruti', 'Brand_Nissan', 'Brand_Other', 'Brand_Renault', 'Brand_Skoda', 'Brand_Tata', 'Brand_Toyota', 'Brand_Volkswagen', 'Model_ASTOR', 'Model_AURA', 'Model_Alto', 'Model_Alto 800', 'Model_Alto K10', 'Model_Amaze', 'Model_Ameo', 'Model_BR-V', 'Model_BREZZA', 'Model_Baleno', 'Model_Beat', 'Model_Brio', 'Model_CARENS', 'Model_Celerio', 'Model_Ciaz', 'Model_City', 'Model_Compass', 'Model_Corolla Altis', 'Model_Creta', 'Model_Duster', 'Model_Dzire', 'Model_Ecosport', 'Model_Eeco', 'Model_Elite i20', 'Model_Eon', 'Model_Ertiga', 'Model_Etios', 'Model_Etios Liva', 'Model_FRONX', 'Model_Figo', 'Model_Figo Aspire', 'Model_GRAND I10 NIOS', 'Model_Glanza', 'Model_Grand Vitara', 'Model_Grand i10', 'Model_HECTOR', 'Model_HECTOR PLUS', 'Model_Harrier', 'Model_Hexa', 'Model_IGNIS', 'Model_Innova', 'Model_Innova Crysta', 'Model_Jazz', 'Model_KUSHAQ', 'Model_Kiger', 'Model_Kuv100', 'Model_Kwid', 'Model_MAGNITE', 'Model_Micra', 'Model_NEW I20', 'Model_NEW SANTRO', 'Model_NEXON', 'Model_NEXON EV', 'Model_New Wagon-R', 'Model_Octavia', 'Model_Other', 'Model_PUNCH', 'Model_Polo', 'Model_Rapid', 'Model_Redi Go', 'Model_Ritz', 'Model_S Cross', 'Model_S PRESSO', 'Model_SELTOS', 'Model_SLAVIA', 'Model_SONET', 'Model_Safari', 'Model_Santro Xing', 'Model_Scorpio', 'Model_Superb', 'Model_Swift', 'Model_Swift Dzire', 'Model_TAIGUN', 'Model_TIGOR', 'Model_TRIBER', 'Model_TUV300', 'Model_Thar', 'Model_Tiago', 'Model_VENUE', 'Model_Vento', 'Model_Verna', 'Model_Vitara Brezza', 'Model_WR-V', 'Model_Wagon R 1.0', 'Model_XL6', 'Model_XUV300', 'Model_XUV500', 'Model_XUV700', 'Model_Xcent', 'Model_Zest', 'Model_i10', 'Model_i20', 'Model_i20 Active', 'Engine_Type_Other', 'Engine_Type_Petrol', 'Transmission_Manual', 'Location_Bangalore', 'Location_Chennai', 'Location_Delhi', 'Location_Gurgaon', 'Location_Hyderabad', 'Location_Mumbai', 'Location_Pune', 'State_Bihar', 'State_Delhi', 'State_Goa', 'State_Gujarat', 'State_Haryana', 'State_Karnataka', 'State_Kerala', 'State_Madhya Pradesh', 'State_Maharashtra', 'State_Punjab', 'State_Rajasthan', 'State_Tamil Nadu', 'State_Telangana', 'State_Uttar Pradesh', 'State_West Bengal']

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.2,    # 80% train, 20% test
    random_state=42   # Same split every time you run
)

print("="*45)
print("TRAIN-TEST SPLIT RESULTS")
print("="*45)
print(f"Total records    : {len(X)}")
print(f"Training records : {len(X_train)}  (80%)")
print(f"Testing records  : {len(X_test)}   (20%)")
print(f"Total features   : {X_train.shape[1]}")
# Out:
# =============================================
# TRAIN-TEST SPLIT RESULTS
# =============================================
# Total records    : 14276
# Training records : 11420  (80%)
# Testing records  : 2856   (20%)
# Total features   : 136

# %%
scaler = StandardScaler()

# CRITICAL RULE — never forget this:
# fit_transform on TRAIN → learns scale from training data
# transform only on TEST → applies same scale (never relearn!)

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled  = scaler.transform(X_test)

print("Scaling complete!")
print(f"X_train shape: {X_train_scaled.shape}")
print(f"X_test shape : {X_test_scaled.shape}")

# Verify scaling worked
print(f"\nBefore scaling — Driven_Kms mean: {X_train['Driven_Kms'].mean():.0f}")
print(f"After scaling  — Mean ≈ 0, Std ≈ 1 (standardized)")
# Out:
# Scaling complete!
# X_train shape: (11420, 136)
# X_test shape : (2856, 136)
#
# Before scaling — Driven_Kms mean: 72905
# After scaling  — Mean ≈ 0, Std ≈ 1 (standardized)

# %%
# Save scaler
pickle.dump(scaler, open('scaler.pkl', 'wb'))

# Save column names — VERY IMPORTANT for web app
column_names = X.columns.tolist()
pickle.dump(column_names, open('model_columns.pkl', 'wb'))

# Save train/test data for Stage 5
np.save('X_train.npy', X_train_scaled)
np.save('X_test.npy',  X_test_scaled)
np.save('y_train.npy', y_train.values)
np.save('y_test.npy',  y_test.values)

print("✅ Files saved:")
print("   → scaler.pkl")
print("   → model_columns.pkl")
print("   → X_train.npy")
print("   → X_test.npy")
print("   → y_train.npy")
print("   → y_test.npy")
# Out:
# ✅ Files saved:
#    → scaler.pkl
#    → model_columns.pkl
#    → X_train.npy
#    → X_test.npy
#    → y_train.npy
#    → y_test.npy

# %%
# Check if this is an issue
print("Rows lost:", 14800 - 14276)  # = 524 rows

# Find where they went
for col in ['Brand', 'Model', 'Engine_Type', 
            'Transmission', 'Location', 'State']:
    print(f"{col} nulls: {df[col].isnull().sum()}")
# Out:
# Rows lost: 524
# Brand nulls: 0
# Model nulls: 0
# Engine_Type nulls: 0
# Transmission nulls: 0
# Location nulls: 0
# State nulls: 0

# %%
import numpy as np
import pandas as pd
import pickle
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, r2_score
from xgboost import XGBRegressor

# Load everything saved in Stage 4
X_train = np.load('X_train.npy')
X_test  = np.load('X_test.npy')
y_train = np.load('y_train.npy')
y_test  = np.load('y_test.npy')

print("✅ Data loaded successfully!")
print(f"X_train : {X_train.shape}")   # (11420, 136)
print(f"X_test  : {X_test.shape}")    # (2856, 136)
print(f"y_train : {y_train.shape}")   # (11420,)
print(f"y_test  : {y_test.shape}")    # (2856,)
# Out:
# ✅ Data loaded successfully!
# X_train : (11420, 136)
# X_test  : (2856, 136)
# y_train : (11420,)
# y_test  : (2856,)

# %%
def evaluate_model(name, y_true_log, y_pred_log):
    """
    Takes log-scale predictions,
    converts back to Lakhs,
    then measures accuracy
    """
    # Convert from log scale back to actual Lakhs
    y_true = np.expm1(y_true_log)
    y_pred = np.expm1(y_pred_log)

    mae  = mean_absolute_error(y_true, y_pred)
    r2   = r2_score(y_true, y_pred)

    # Mean Absolute Percentage Error
    mape = np.mean(np.abs((y_true - y_pred) / y_true)) * 100

    print(f"\n{'='*45}")
    print(f"  {name}")
    print(f"{'='*45}")
    print(f"  MAE   : ₹{mae:.4f} Lakhs")
    print(f"         (avg prediction is off by ₹{mae:.2f}L)")
    print(f"  MAPE  : {mape:.2f}%")
    print(f"         (avg % error per prediction)")
    print(f"  R²    : {r2:.4f}  ({r2*100:.1f}%)")
    print(f"         (model explains {r2*100:.1f}% of price variation)")

    if r2 >= 0.90:
        print("  Verdict : 🟢 Excellent!")
    elif r2 >= 0.80:
        print("  Verdict : 🟡 Good")
    elif r2 >= 0.70:
        print("  Verdict : 🟠 Acceptable")
    else:
        print("  Verdict : 🔴 Needs Improvement")

    return mae, r2, mape

# %% [markdown]
# ```
#
# ### What these 3 metrics mean in plain English:
# ```
# MAE (Mean Absolute Error):
# → On average, your prediction is off by ₹X Lakhs
# → If MAE = 0.65 → predictions are ₹65,000 off on average
# → Lower is better
#
# MAPE (Mean Absolute Percentage Error):
# → On average, your prediction is off by X%
# → If MAPE = 12% → for a ₹5L car, prediction could be ₹4.4L or ₹5.6L
# → Lower is better
#
# R² Score:
# → How much of price variation your model explains
# → R² = 0.92 → model correctly explains 92% of why prices differ
# → Higher is better (max = 1.0)

# %%
print("\n🔄 Training Linear Regression...")

lr_model = LinearRegression()
lr_model.fit(X_train, y_train)

lr_pred = lr_model.predict(X_test)

print("✅ Linear Regression trained!")
lr_mae, lr_r2, lr_mape = evaluate_model(
    "Linear Regression", y_test, lr_pred
)
# Out:
# 🔄 Training Linear Regression...
# ✅ Linear Regression trained!
#
# =============================================
#   Linear Regression
# =============================================
#   MAE   : ₹0.6171 Lakhs
#          (avg prediction is off by ₹0.62L)
#   MAPE  : 14.84%
#          (avg % error per prediction)
#   R²    : 0.8712  (87.1%)
#          (model explains 87.1% of price variation)
#   Verdict : 🟡 Good

# %% [markdown]
# ### What Linear Regression does with YOUR data:
# ```
# Learns one equation like:
#
# Price = (−0.12 × Car_Age)
#       + (−0.000003 × Driven_Kms)
#       + (0.45 × Brand_KIA)
#       + (0.38 × Transmission_Auto)
#       + ... (136 terms total)
#
# Simple but CANNOT capture:
# → A 1-year-old car loses value faster than a 10-year-old one
# → Luxury brands have non-linear pricing jumps
# → City + age combinations that interact with each other

# %%
print("\n🔄 Training Random Forest...")
print("    (This takes 1-3 minutes — normal!)")

rf_model = RandomForestRegressor(
    n_estimators=200,     # 200 decision trees
    max_depth=15,         # Each tree can go 15 levels deep
    min_samples_split=5,  # Need 5+ samples to split a node
    min_samples_leaf=2,   # Each leaf needs 2+ samples
    random_state=42,
    n_jobs=-1             # Use ALL CPU cores → faster training
)

rf_model.fit(X_train, y_train)
rf_pred = rf_model.predict(X_test)

print("✅ Random Forest trained!")
rf_mae, rf_r2, rf_mape = evaluate_model(
    "Random Forest", y_test, rf_pred
)
# Out:
# 🔄 Training Random Forest...
#     (This takes 1-3 minutes — normal!)
# ✅ Random Forest trained!
#
# =============================================
#   Random Forest
# =============================================
#   MAE   : ₹0.7488 Lakhs
#          (avg prediction is off by ₹0.75L)
#   MAPE  : 17.39%
#          (avg % error per prediction)
#   R²    : 0.8321  (83.2%)
#          (model explains 83.2% of price variation)
#   Verdict : 🟡 Good

# %% [markdown]
# ```
#
# ### What Random Forest does with YOUR data:
# ```
# Builds 200 decision trees, each slightly different.
#
# Example of ONE tree's thinking:
# Is Car_Age > 7?
# ├── YES → Is Brand_Maruti = 1?
# │         ├── YES → Price ≈ ₹2.8L
# │         └── NO  → Is Driven_Kms > 100000?
# │                   ├── YES → Price ≈ ₹3.5L
# │                   └── NO  → Price ≈ ₹4.8L
# └── NO  → Is Transmission_Manual = 1?
#           ├── YES → Price ≈ ₹5.2L
#           └── NO  → Price ≈ ₹7.9L
#
# 200 trees each vote → take the average
# Much smarter than one straight line! ✅

# %%
print("\n🔄 Training XGBoost...")

xgb_model = XGBRegressor(
    n_estimators=500,        # 500 trees built sequentially
    learning_rate=0.05,      # Each tree corrects 5% of error
    max_depth=6,             # Controlled tree depth
    subsample=0.8,           # Each tree uses 80% of rows
    colsample_bytree=0.8,    # Each tree uses 80% of features
    min_child_weight=3,      # Minimum samples in leaf
    reg_alpha=0.1,           # L1 regularization (prevents overfitting)
    reg_lambda=1.0,          # L2 regularization (prevents overfitting)
    random_state=42,
    n_jobs=-1,
    verbosity=0              # Silent mode
)

xgb_model.fit(
    X_train, y_train,
    eval_set=[(X_test, y_test)],
    verbose=100              # Print score every 100 rounds
)

xgb_pred = xgb_model.predict(X_test)

print("\n✅ XGBoost trained!")
xgb_mae, xgb_r2, xgb_mape = evaluate_model(
    "XGBoost", y_test, xgb_pred
)
# Out:
# 🔄 Training XGBoost...
# [0]	validation_0-rmse:0.45796
# [100]	validation_0-rmse:0.17116
# [200]	validation_0-rmse:0.14931
# [300]	validation_0-rmse:0.13973
# [400]	validation_0-rmse:0.13355
# [499]	validation_0-rmse:0.12909
#
# ✅ XGBoost trained!
#
# =============================================
#   XGBoost
# =============================================
#   MAE   : ₹0.5459 Lakhs
#          (avg prediction is off by ₹0.55L)
#   MAPE  : 12.76%
#          (avg % error per prediction)
#   R²    : 0.9023  (90.2%)
#          (model explains 90.2% of price variation)
#   Verdict : 🟢 Excellent!

# %% [markdown]
# ```
#
# ### What XGBoost does with YOUR data:
# ```
# Round 1:   Tree 1 predicts prices → makes errors
# Round 2:   Tree 2 ONLY focuses on fixing Round 1's mistakes
# Round 3:   Tree 3 fixes Round 2's remaining mistakes
# ...
# Round 500: Each round the model gets smarter
#
# For YOUR dataset:
# → Round 1 might miss that KIA in Bangalore is expensive
# → Round 2 learns this correction
# → Round 50 has learned almost every city-brand pattern
# → Round 500 has captured very fine-grained pricing signals

# %%
print("\n" + "="*50)
print("  FINAL MODEL COMPARISON")
print("="*50)
print(f"{'Model':<22} {'MAE (₹L)':<12} {'MAPE %':<12} {'R²':<10}")
print("-"*56)
print(f"{'Linear Regression':<22} {lr_mae:<12.4f} {lr_mape:<12.2f} {lr_r2:<10.4f}")
print(f"{'Random Forest':<22} {rf_mae:<12.4f} {rf_mape:<12.2f} {rf_r2:<10.4f}")
print(f"{'XGBoost':<22} {xgb_mae:<12.4f} {xgb_mape:<12.2f} {xgb_r2:<10.4f}")
print("="*50)

# Pick the best model automatically
models = {
    'Linear Regression': (lr_r2, lr_model, lr_pred),
    'Random Forest':     (rf_r2, rf_model, rf_pred),
    'XGBoost':           (xgb_r2, xgb_model, xgb_pred)
}
best_name = max(models, key=lambda x: models[x][0])
best_r2, best_model, best_pred = models[best_name]

print(f"\n🏆 Best Model: {best_name}")
print(f"   R² Score  : {best_r2:.4f}")
# Out:
# ==================================================
#   FINAL MODEL COMPARISON
# ==================================================
# Model                  MAE (₹L)     MAPE %       R²
# --------------------------------------------------------
# Linear Regression      0.6171       14.84        0.8712
# Random Forest          0.7488       17.39        0.8321
# XGBoost                0.5459       12.76        0.9023
# ==================================================
#
# 🏆 Best Model: XGBoost
#    R² Score  : 0.9023

# %%
fig, axes = plt.subplots(1, 3, figsize=(18, 5))

model_results = [
    ("Linear Regression", lr_pred,  lr_r2),
    ("Random Forest",     rf_pred,  rf_r2),
    ("XGBoost",           xgb_pred, xgb_r2),
]

y_actual = np.expm1(y_test)

for ax, (name, pred_log, r2) in zip(axes, model_results):
    pred_actual = np.expm1(pred_log)

    ax.scatter(y_actual, pred_actual, 
               alpha=0.2, s=8, color='steelblue')

    # Perfect prediction line
    min_val = min(y_actual.min(), pred_actual.min())
    max_val = max(y_actual.max(), pred_actual.max())
    ax.plot([min_val, max_val], [min_val, max_val],
            'r--', linewidth=2, label='Perfect prediction')

    ax.set_title(f'{name}\nR² = {r2:.4f}', 
                 fontsize=12, fontweight='bold')
    ax.set_xlabel('Actual Price (Lakhs)')
    ax.set_ylabel('Predicted Price (Lakhs)')
    ax.legend(fontsize=8)

plt.suptitle('Actual vs Predicted Prices — All 3 Models',
             fontsize=15, fontweight='bold')
plt.tight_layout()
plt.savefig('model_comparison.png', dpi=150)
plt.show()

# %% [markdown]
# ```
#
# ### How to read this chart:
# ```
# Dots exactly ON the red line  → Perfect prediction ✅
# Dots scattered FAR from line  → Model is wrong ❌
#
# You'll see:
# Linear Regression → dots spread wide, far from line
# Random Forest     → dots much closer to the line
# XGBoost           → tightest cluster around the line ✅

# %%
# Load column names
model_columns = pickle.load(open('model_columns.pkl', 'rb'))

# Get feature importances from Random Forest
rf_importances = rf_model.feature_importances_

feat_df = pd.DataFrame({
    'Feature':    model_columns,
    'Importance': rf_importances
}).sort_values('Importance', ascending=False).head(15)

plt.figure(figsize=(10, 7))
plt.barh(feat_df['Feature'][::-1], 
         feat_df['Importance'][::-1], 
         color='steelblue')
plt.title('Top 15 Features Driving Car Price',
          fontsize=15, fontweight='bold')
plt.xlabel('Importance Score')
plt.tight_layout()
plt.savefig('feature_importance.png', dpi=150)
plt.show()

print("\nTop 10 Price Drivers:")
print(feat_df.head(10).to_string(index=False))
# Out:
# Top 10 Price Drivers:
#             Feature  Importance
#             Car_Age        0.65
#         Brand_Other        0.04
# Transmission_Manual        0.04
#         Model_Creta        0.03
#          Model_Kwid        0.02
#      Location_Delhi        0.02
#     State_Karnataka        0.02
#          Driven_Kms        0.01
#        Model_Ertiga        0.01
#  Engine_Type_Petrol        0.01

# %% [markdown]
# ```
#
# You'll likely see:
# ```
# Top 10 Price Drivers:
# Feature            Importance
# Car_Age               0.38    ← #1 by far
# Driven_Kms            0.18    ← #2
# Brand_KIA             0.05
# Brand_MG              0.04
# Transmission_Manual   0.03
# Brand_Mahindra        0.03
# Location_Bangalore    0.02
# Engine_Type_Petrol    0.02
# is_top_trim           0.02
# Brand_Tata            0.01

# %%
# Let's test with the first car in your dataset:
# KIA SONET, Petrol, Manual, 2022, 43,447 km, Delhi
# Real price: ₹6.21 Lakhs

y_actual_all  = np.expm1(y_test)
y_pred_best   = np.expm1(best_pred)

# Show first 10 predictions vs actual
print("\nSample Predictions vs Actual:")
print(f"{'Actual (₹L)':<15} {'Predicted (₹L)':<18} {'Error (₹L)':<12}")
print("-"*45)
for actual, predicted in zip(y_actual_all[:10], y_pred_best[:10]):
    error = abs(actual - predicted)
    print(f"₹{actual:<14.2f} ₹{predicted:<17.2f} ₹{error:.2f}")
# Out:
# Sample Predictions vs Actual:
# Actual (₹L)     Predicted (₹L)     Error (₹L)
# ---------------------------------------------
# ₹4.40           ₹4.27              ₹0.13
# ₹8.23           ₹5.90              ₹2.33
# ₹1.00           ₹1.61              ₹0.61
# ₹2.78           ₹2.69              ₹0.09
# ₹2.04           ₹1.94              ₹0.10
# ₹2.79           ₹3.12              ₹0.33
# ₹7.09           ₹8.04              ₹0.95
# ₹5.82           ₹6.78              ₹0.96
# ₹8.65           ₹8.01              ₹0.64
# ₹4.56           ₹4.39              ₹0.17

# %%
import pickle

# Save best model
pickle.dump(best_model, open('best_model.pkl', 'wb'))

# Also save all 3 for comparison
pickle.dump(lr_model,  open('lr_model.pkl',  'wb'))
pickle.dump(rf_model,  open('rf_model.pkl',  'wb'))
pickle.dump(xgb_model, open('xgb_model.pkl', 'wb'))

print("✅ All models saved!")
print(f"\n🏆 Best model → best_model.pkl")
print(f"   This is your: {best_name}")
print(f"   R² Score    : {best_r2:.4f}")
print(f"   Ready for deployment!")
# Out:
# ✅ All models saved!
#
# 🏆 Best model → best_model.pkl
#    This is your: XGBoost
#    R² Score    : 0.9023
#    Ready for deployment!
